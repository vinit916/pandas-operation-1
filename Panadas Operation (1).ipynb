# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s=df['Name'][0:10]

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
l=['a','b','c','d','e','f','g','h','i','j']

# %%
s1=pd.Series(list(s),index=l)

# %%
s1
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# f                                     Moran, Mr. James
# g                              McCarthy, Mr. Timothy J
# h                       Palsson, Master. Gosta Leonard
# i    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
df.drop('PassengerId',axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(4)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# paramanetaly Delete Data
df.drop('PassengerId',axis=1,inplace=True)
df.drop(4,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#Return to data deleted

# %%
df.reset_index('PassengerId',axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.reset_index('PassengerId',axis=1)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: DataFrame.reset_index() got an unexpected keyword argument 'axis'

# %%
df1=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Group Data
g=df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_110/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1387  12950.50    304    181  12134.6699
# 1            667   8219.67    162    159  16551.2294

# %%
g.max()
# Out:
# /tmp/ipykernel_110/2609361031.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g.max()
#           Pclass                         Name   Sex   Age  SibSp  Parch  \
# Survived
# 0              3  van Melkebeke, Mr. Philemon  male  74.0      8      6
# 1              3      de Mulder, Mr. Theodore  male  80.0      4      5
#
#              Ticket      Fare
# Survived
# 0         WE/P 5735  263.0000
# 1         WE/P 5735  512.3292

# %%
g.mean()
# Out:
# /tmp/ipykernel_110/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531022  30.615839  0.554745  0.330292  22.143558
# 1         1.950292  28.343690  0.473684  0.464912  48.395408

# %%
g.std()
# Out:
# /tmp/ipykernel_110/1591525991.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.std()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         0.736205  14.187290  1.289359  0.823797  31.411116
# 1         0.863321  14.950952  0.708688  0.771712  66.596998

# %%
g1=df.groupby('Pclass')

# %%
g1.max().T
# Out:
# /tmp/ipykernel_110/2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                           1                          2  \
# Survived                         1                          1
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Survived                            1
# Name      van Melkebeke, Mr. Philemon
# ...

# %%
d={'key1':[1,2,3,4,5],
    'key2':['zena','ajooba','neon','matrix','jalal'],
    'Key3':[34,45,21,25,57]
  }

# %%
pd.DataFrame(d)
# Out:
#    key1    key2  Key3
# 0     1    zena    34
# 1     2  ajooba    45
# 2     3    neon    21
# 3     4  matrix    25
# 4     5   jalal    57

# %%
df2=df1[['PassengerId','Survived','Pclass','Name']][0:6]

# %%
df3=df1[['PassengerId','Survived','Pclass','Name']][7:11]

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
# 5                                   Moran, Mr. James

# %%
df3
# Out:
#     PassengerId  Survived  Pclass  \
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name
# 7                      Palsson, Master. Gosta Leonard
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                 Nasser, Mrs. Nicholas (Adele Achem)
# 10                    Sandstrom, Miss. Marguerite Rut

# %%
pd.concat([df2,df3])
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name
# 0                             Braund, Mr. Owen Harris
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                              Heikkinen, Miss. Laina
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                            Allen, Mr. William Henry
# 5                                    Moran, Mr. James
# 7                      Palsson, Master. Gosta Leonard
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                 Nasser, Mrs. Nicholas (Adele Achem)
# ...

# %%
df4=pd.concat([df2,df3],axis=1)

# %%
df4.fillna('vinit')
# Out:
#    PassengerId Survived Pclass  \
# 0          1.0      0.0    3.0
# 1          2.0      1.0    1.0
# 2          3.0      1.0    3.0
# 3          4.0      1.0    1.0
# 4          5.0      0.0    3.0
# 5          6.0      0.0    3.0
# 7        vinit    vinit  vinit
# 8        vinit    vinit  vinit
# 9        vinit    vinit  vinit
# 10       vinit    vinit  vinit
#
#                                                  Name PassengerId Survived  \
# 0                             Braund, Mr. Owen Harris       vinit    vinit
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...       vinit    vinit
# 2                              Heikkinen, Miss. Laina       vinit    vinit
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)       vinit    vinit
# 4                            Allen, Mr. William Henry       vinit    vinit
# 5                                    Moran, Mr. James       vinit    vinit
# 7                                               vinit         8.0      0.0
# ...

# %%
#Merge Data
data1=pd.DataFrame({'key1':[1,2,3,4,5],
    'key2':[2,3,5,6,7],
    'Key3':[40,11,21,23,53]
  })

# %%
data2=pd.DataFrame({'key1':[1,2,33,4,45],
    'key4':[2,35,5,6,7],
    'Key5':[34,45,21,25,57]
  })

# %%
data1
# Out:
#    key1  key2  Key3
# 0     1     2    40
# 1     2     3    11
# 2     3     5    21
# 3     4     6    23
# 4     5     7    53

# %%
data2
# Out:
#    key1  key4  Key5
# 0     1     2    34
# 1     2    35    45
# 2    33     5    21
# 3     4     6    25
# 4    45     7    57

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  Key3  key4  Key5
# 0     1     2    40     2    34
# 1     2     3    11    35    45
# 2     4     6    23     6    25

# %%
pd.merge(data1,data2,how='outer')
# Out:
#    key1  key2  Key3  key4  Key5
# 0     1   2.0  40.0   2.0  34.0
# 1     2   3.0  11.0  35.0  45.0
# 2     3   5.0  21.0   NaN   NaN
# 3     4   6.0  23.0   6.0  25.0
# 4     5   7.0  53.0   NaN   NaN
# 5    33   NaN   NaN   5.0  21.0
# 6    45   NaN   NaN   7.0  57.0

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  Key3  key4  Key5
# 0     1     2    40   2.0  34.0
# 1     2     3    11  35.0  45.0
# 2     3     5    21   NaN   NaN
# 3     4     6    23   6.0  25.0
# 4     5     7    53   NaN   NaN

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  Key3  key4  Key5
# 0     1   2.0  40.0     2    34
# 1     2   3.0  11.0    35    45
# 2    33   NaN   NaN     5    21
# 3     4   6.0  23.0     6    25
# 4    45   NaN   NaN     7    57

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  Key3  key1_y  key4  Key5
# 0        1     2    40       1     2    34
# 1        1     2    40       2    35    45
# 2        1     2    40      33     5    21
# 3        1     2    40       4     6    25
# 4        1     2    40      45     7    57
# 5        2     3    11       1     2    34
# 6        2     3    11       2    35    45
# 7        2     3    11      33     5    21
# 8        2     3    11       4     6    25
# 9        2     3    11      45     7    57
# 10       3     5    21       1     2    34
# 11       3     5    21       2    35    45
# 12       3     5    21      33     5    21
# 13       3     5    21       4     6    25
# 14       3     5    21      45     7    57
# 15       4     6    23       1     2    34
# 16       4     6    23       2    35    45
# 17       4     6    23      33     5    21
# 18       4     6    23       4     6    25
# 19       4     6    23      45     7    57
# 20       5     7    53       1     2    34
# ...

# %%
# Join Operation
data3=pd.DataFrame({'key1':[1,2,3,4,5],
    'key2':[2,3,5,6,7],
    'Key3':[40,11,21,23,53]
  },index=['a','b','c','d','e']
                  )

# %%
data4=pd.DataFrame({'key11':[1,2,33,4,45],
    'key4':[2,35,5,6,7],
    'Key5':[34,45,21,25,57]
  },index=['a','b','f','g','h'])

# %%
data3.join(data4)
# Out:
#    key1  key2  Key3  key11  key4  Key5
# a     1     2    40    1.0   2.0  34.0
# b     2     3    11    2.0  35.0  45.0
# c     3     5    21    NaN   NaN   NaN
# d     4     6    23    NaN   NaN   NaN
# e     5     7    53    NaN   NaN   NaN

# %%
data3.join(data4,how='right')
# Out:
#    key1  key2  Key3  key11  key4  Key5
# a   1.0   2.0  40.0      1     2    34
# b   2.0   3.0  11.0      2    35    45
# f   NaN   NaN   NaN     33     5    21
# g   NaN   NaN   NaN      4     6    25
# h   NaN   NaN   NaN     45     7    57

# %%
data3.join(data4,how='left')
# Out:
#    key1  key2  Key3  key11  key4  Key5
# a     1     2    40    1.0   2.0  34.0
# b     2     3    11    2.0  35.0  45.0
# c     3     5    21    NaN   NaN   NaN
# d     4     6    23    NaN   NaN   NaN
# e     5     7    53    NaN   NaN   NaN

# %%
data3.join(data4,how='outer')
# Out:
#    key1  key2  Key3  key11  key4  Key5
# a   1.0   2.0  40.0    1.0   2.0  34.0
# b   2.0   3.0  11.0    2.0  35.0  45.0
# c   3.0   5.0  21.0    NaN   NaN   NaN
# d   4.0   6.0  23.0    NaN   NaN   NaN
# e   5.0   7.0  53.0    NaN   NaN   NaN
# f   NaN   NaN   NaN   33.0   5.0  21.0
# g   NaN   NaN   NaN    4.0   6.0  25.0
# h   NaN   NaN   NaN   45.0   7.0  57.0

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1['Fare_INR']=df1['Fare'].apply(lambda x:x*80)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def cat_Fare(x):
    if x<10:
        return 'cheap'
    elif x>=10 and x<20:
        return 'mid'
    else:
        return 'high'

# %%
df1['cat_Fare']=df1['Fare'].apply(cat_Fare)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
